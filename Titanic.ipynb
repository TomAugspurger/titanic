# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv', index_col=0)
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C
#
# [2 rows x 11 columns]

# %% [markdown]
# Classify new features:
#
# - child : age < 16
# - woman_or_child

# %%
df.columns = df.columns.map(lambda x: x.lower())

def woman_child_or_man(passenger):
    age, sex = passenger
    if age < 16:
        return "child"
    else:
        return dict(male="man", female="woman")[sex]

df['who'] = df[['age', 'sex']].apply(woman_child_or_man, axis=1)
df["alone"] = ~(df.parch + df.sibsp).astype(bool)
df["class"] = df.pclass.map({1: "First", 2: "Second", 3: "Third"})
df["deck"] = df.cabin.str[0].map(lambda s: np.nan if s == "T" else s)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-154-bb4a80610849> in <module>()
#      11 df["alone"] = ~(df.parch + df.sibsp).astype(bool)
#      12 df["class"] = df.pclass.map({1: "First", 2: "Second", 3: "Third"})
# ---> 13 df["deck"] = df.cabin.str[0].map(lambda s: np.nan if s == "T" else s)
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/pandas/lib.so in pandas.lib.cache_readonly.__get__ (pandas/lib.c:29584)()
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/pandas/core/series.py in str(self)
#
# ImportError: No module named 'pandas.core.strings'

# %%
df.head()
# Out:
#              survived  pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           name     sex  age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
#
#              sibsp  parch            ticket     fare cabin embarked    who  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    man
# 2                1      0          PC 17599  71.2833   C85        C  woman
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  woman
# 4                1      0            113803  53.1000  C123        S  woman
# 5                0      0            373450   8.0500   NaN        S    man
#
#              alone
# PassengerId
# 1            False
# 2            False
# 3             True
# 4            False
# 5             True
#
# [5 rows x 13 columns]

# %% [markdown]
# Bit of visualization before diving in (for a better version see http://nbviewer.ipython.org/gist/mwaskom/8224591)

# %%
from missmap import missmap
missmap(df)

# %% [markdown]
# Demographics on Passengers

# %%
pal = dict(man="#4682B4", woman="#CD5C5C", child="#2E8B57", male="#6495ED", female="#F08080")

sns.factorplot("who", data=df, palette=pal)

# %%
sns.factorplot("class", data=df, hue="who", palette=pal)

# %%
ax = sns.kdeplot(df.age, shade=True)
# ax.set_xlim(0, 80)  # matplotlib doesn't redraw

# %%
g = sns.FacetGrid(df, hue="who", aspect=3, palette=pal)
g.map(sns.kdeplot, "age", shade=True)

# %%
# who's age is missing
df['bad_age'] = pd.isnull(df.age)
df.groupby(['sex', 'class'])['bad_age'].agg('sum')
# Out:
# sex     class
# female  First      9
#         Second     2
#         Third     42
# male    First     21
#         Second     9
#         Third     94
# Name: bad_age, dtype: float64

# %%
# relative
df['bad_age'] = pd.isnull(df.age)
df.groupby(['sex', 'class'])['bad_age'].agg('mean')
# Out:
# sex     class
# female  First     0.095745
#         Second    0.026316
#         Third     0.291667
# male    First     0.172131
#         Second    0.083333
#         Third     0.270893
# Name: bad_age, dtype: float64

# %%
sns.factorplot("class", data=df, palette="PuBu_d")

# %%
g = sns.FacetGrid(df, hue="class", aspect=3, palette="PuBu_d")
g.map(sns.kdeplot, "age", shade=True)
#g.set(xlim=(0, 80))

# %%
fg = sns.FacetGrid(df, col="sex", row="class", hue="sex", size=2.5, aspect=2.5, palette=pal)
fg.map(sns.kdeplot, "age", shade=True)
fg.map(sns.rugplot, "age")
sns.despine(left=True)
fg.set(xlim=(0, 80));

# %%
sns.factorplot("deck", hue="class", data=df, palette="BuPu_d");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-69300521561e> in <module>()
# ----> 1 sns.factorplot("deck", hue="class", data=df, palette="BuPu_d");
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/seaborn-0.4.dev-py3.4.egg/seaborn/linearmodels.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, x_order, hue_order, col_order, row_order, kind, markers, linestyles, dodge, join, hline, size, aspect, palette, legend, legend_out, dropna, sharex, sharey, margin_titles)
#     827     cols = [a for a in [x, y, hue, col, row, units] if a is not None]
#     828     cols = pd.unique(cols).tolist()
# --> 829     data = data[cols]
#     830
#     831     facet_hue = hue if hue in [row, col] else None
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#
# /Users/admin/Envs/py3/lib/python3.4/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#
# KeyError: "['deck'] not in index"

# %% [markdown]
# ## Who Survived?

# %%
sns.factorplot("survived", data=df, palette="BuPu_r")

# %%
sns.
